# %% [markdown]
# <a href="https://colab.research.google.com/github/fransarisdan/desafio_enem_alura/blob/main/ENEM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/MyDrive/MICRODADOS_ENEM_2021.csv'

data_enem = pd.read_csv(path, encoding='ISO-8859-1', sep=';')

# %%
data_enem
# Out:
#          NU_INSCRICAO  NU_ANO  TP_FAIXA_ETARIA TP_SEXO  TP_ESTADO_CIVIL  \
# 0        210053865474    2021                5       F                1
# 1        210052384164    2021               12       M                1
# 2        210052589243    2021               13       F                3
# 3        210052128335    2021                3       M                1
# 4        210051353021    2021                2       F                1
# ...               ...     ...              ...     ...              ...
# 3389827  210053249138    2021                7       F                1
# 3389828  210053776013    2021                7       F                1
# 3389829  210052441508    2021               13       F                1
# 3389830  210051139675    2021                7       F                1
# 3389831  210052410399    2021               12       F                2
#
#          TP_COR_RACA  TP_NACIONALIDADE  TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  \
# 0                  1                 1                1                3
# 1                  1                 1                1               11
# 2                  1                 1                1               15
# 3                  3                 1                2                0
# 4                  3                 1                2                0
# ...              ...               ...              ...              ...
# 3389827            3                 1                1                0
# 3389828            1                 1                1                5
# 3389829            3                 1                1               15
# 3389830            1                 1                1                4
# 3389831            3                 1                1               15
#
#          TP_ESCOLA  ...  Q016  Q017  Q018 Q019  Q020 Q021  Q022  Q023  Q024  \
# 0                1  ...     A     A     A    B     A    A     B     A     B
# 1                1  ...     A     A     A    B     A    A     C     A     A
# 2                1  ...     B     A     A    B     A    A     C     B     B
# 3                2  ...     A     A     A    B     A    A     B     A     B
# 4                2  ...     B     A     A    B     A    B     E     A     B
# ...            ...  ...   ...   ...   ...  ...   ...  ...   ...   ...   ...
# 3389827          1  ...     A     A     A    B     A    A     B     A     A
# 3389828          1  ...     B     A     B    C     A    A     E     B     B
# 3389829          1  ...     B     A     A    A     A    A     B     A     B
# 3389830          1  ...     B     A     B    B     A    B     E     A     C
# 3389831          1  ...   NaN   NaN   NaN  NaN   NaN  NaN   NaN   NaN   NaN
#
#          Q025
# 0           B
# 1           A
# 2           B
# 3           B
# 4           B
# ...       ...
# 3389827     B
# 3389828     B
# 3389829     B
# 3389830     B
# 3389831   NaN
#
# [3389832 rows x 76 columns]

# %%
linhas=len(data_enem.axes[0])
colunas=len(data_enem.axes[1])

print("O numero total de linhas é " +str(linhas))
print("E o numero total de colunas é " +str(colunas))
# Out:
# O numero total de linhas é 3389832
# E o numero total de colunas é 76

# %%
headers = data_enem.columns
headers
# Out:
# Index(['NU_INSCRICAO', 'NU_ANO', 'TP_FAIXA_ETARIA', 'TP_SEXO',
#        'TP_ESTADO_CIVIL', 'TP_COR_RACA', 'TP_NACIONALIDADE', 'TP_ST_CONCLUSAO',
#        'TP_ANO_CONCLUIU', 'TP_ESCOLA', 'TP_ENSINO', 'IN_TREINEIRO',
#        'CO_MUNICIPIO_ESC', 'NO_MUNICIPIO_ESC', 'CO_UF_ESC', 'SG_UF_ESC',
#        'TP_DEPENDENCIA_ADM_ESC', 'TP_LOCALIZACAO_ESC', 'TP_SIT_FUNC_ESC',
#        'CO_MUNICIPIO_PROVA', 'NO_MUNICIPIO_PROVA', 'CO_UF_PROVA',
#        'SG_UF_PROVA', 'TP_PRESENCA_CN', 'TP_PRESENCA_CH', 'TP_PRESENCA_LC',
#        'TP_PRESENCA_MT', 'CO_PROVA_CN', 'CO_PROVA_CH', 'CO_PROVA_LC',
#        'CO_PROVA_MT', 'NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC', 'NU_NOTA_MT',
#        'TX_RESPOSTAS_CN', 'TX_RESPOSTAS_CH', 'TX_RESPOSTAS_LC',
#        'TX_RESPOSTAS_MT', 'TP_LINGUA', 'TX_GABARITO_CN', 'TX_GABARITO_CH',
#        'TX_GABARITO_LC', 'TX_GABARITO_MT', 'TP_STATUS_REDACAO',
#        'NU_NOTA_COMP1', 'NU_NOTA_COMP2', 'NU_NOTA_COMP3', 'NU_NOTA_COMP4',
#        'NU_NOTA_COMP5', 'NU_NOTA_REDACAO', 'Q001', 'Q002', 'Q003', 'Q004',
#        'Q005', 'Q006', 'Q007', 'Q008', 'Q009', 'Q010', 'Q011', 'Q012', 'Q013',
#        'Q014', 'Q015', 'Q016', 'Q017', 'Q018', 'Q019', 'Q020', 'Q021', 'Q022',
#        'Q023', 'Q024', 'Q025'],
#       dtype='object')

# %%
for posicao, header in enumerate(headers):
  print(posicao, "-", header)
# Out:
# 0 - NU_INSCRICAO
# 1 - NU_ANO
# 2 - TP_FAIXA_ETARIA
# 3 - TP_SEXO
# 4 - TP_ESTADO_CIVIL
# 5 - TP_COR_RACA
# 6 - TP_NACIONALIDADE
# 7 - TP_ST_CONCLUSAO
# 8 - TP_ANO_CONCLUIU
# 9 - TP_ESCOLA
# 10 - TP_ENSINO
# 11 - IN_TREINEIRO
# 12 - CO_MUNICIPIO_ESC
# 13 - NO_MUNICIPIO_ESC
# 14 - CO_UF_ESC
# 15 - SG_UF_ESC
# 16 - TP_DEPENDENCIA_ADM_ESC
# 17 - TP_LOCALIZACAO_ESC
# 18 - TP_SIT_FUNC_ESC
# 19 - CO_MUNICIPIO_PROVA
# 20 - NO_MUNICIPIO_PROVA
# 21 - CO_UF_PROVA
# 22 - SG_UF_PROVA
# 23 - TP_PRESENCA_CN
# 24 - TP_PRESENCA_CH
# 25 - TP_PRESENCA_LC
# 26 - TP_PRESENCA_MT
# 27 - CO_PROVA_CN
# 28 - CO_PROVA_CH
# 29 - CO_PROVA_LC
# 30 - CO_PROVA_MT
# 31 - NU_NOTA_CN
# 32 - NU_NOTA_CH
# 33 - NU_NOTA_LC
# 34 - NU_NOTA_MT
# 35 - TX_RESPOSTAS_CN
# 36 - TX_RESPOSTAS_CH
# 37 - TX_RESPOSTAS_LC
# 38 - TX_RESPOSTAS_MT
# 39 - TP_LINGUA
# 40 - TX_GABARITO_CN
# 41 - TX_GABARITO_CH
# 42 - TX_GABARITO_LC
# 43 - TX_GABARITO_MT
# 44 - TP_STATUS_REDACAO
# 45 - NU_NOTA_COMP1
# 46 - NU_NOTA_COMP2
# 47 - NU_NOTA_COMP3
# 48 - NU_NOTA_COMP4
# 49 - NU_NOTA_COMP5
# 50 - NU_NOTA_REDACAO
# 51 - Q001
# 52 - Q002
# 53 - Q003
# 54 - Q004
# 55 - Q005
# 56 - Q006
# 57 - Q007
# 58 - Q008
# 59 - Q009
# 60 - Q010
# 61 - Q011
# 62 - Q012
# 63 - Q013
# 64 - Q014
# 65 - Q015
# 66 - Q016
# 67 - Q017
# 68 - Q018
# 69 - Q019
# 70 - Q020
# 71 - Q021
# 72 - Q022
# 73 - Q023
# 74 - Q024
# 75 - Q025

# %%
from numpy.core.fromnumeric import mean
data_enem.rename(columns = {'NU_NOTA_REDACAO':'nota_redacao', 'TP_SEXO':'sexo', 'SG_UF_PROVA':'estado'}, inplace = True)

# %%
estados = dict(data_enem['estado'].value_counts())
x = list(estados.keys())
y = list(estados.values())

# %%
plt.bar(x, y, align='center', color = 'hotpink', width=0.8)
plt.xticks(rotation=90, fontweight='normal', fontsize='9', horizontalalignment='center')

plt.show()
